# %%
import math
import numpy as np

path = "/Users/colefritsch/ENCORE/Python_ENCORE/MissingNeuralNets"

with open(f'{path}/1e4_samples_50epts/residual_data.csv', 'r') as file:
    data = file.read()
CS = np.array([[float(el) for el in row.split(',')] for row in data.split('\n')[:-1]])

with open(f'{path}/1e4_samples_50epts/missing_res_.csv', 'r') as file:
    data = file.read()
Ans = np.array([int(el[0]) for el in data.split('\n')[:-1]])



# for idx in range(N):
#     with open(f'{path}/1e4_samples_50epts/synthetic_data/SAMMY_smpl_{idx}.par', 'r') as file:
#         data = file.read()
#     ResE = np.array([float(rows.split(' ')[0]) for rows in data.split('\n')[:-1]])
#     E1 = 55.80000000
#     E2 = 59.05000000
